# %% [markdown]
# <a href="https://colab.research.google.com/github/aekanun2020/Data-Analytics-using-Python/blob/main/A_Python_Pandas_Create_Pandas_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# แนะนำการสร้าง Pandas Dataframe ด้วยวิธีการ 2 แบบ กล่าวคือ
#
# (1) การสร้าง Dataframe ด้วย Constructor
#
# (2) การสร้าง Dataframe ด้วย File Reader

# %% [markdown]
# # **1. Creating Dataframe using Constructor**

# %% [markdown]
# ### **1.1 แนวทางที่ 1 ใช้ Dictionary ทั่วไป**
#
# การนำ List เพียงอย่างเดียวมาสร้างเป็น Dataframe สามารถทำได้ แต่ผลคือ Dataframe อาจจะขาดโครงสร้างสำคัญไป เช่น Column Index Label
#
# ทางออกของกรณีนี้คือ การนำ Dictionary เข้ามาช่วย คือ สร้างเป็น List of Dictionary โดย 1 Dict = 1 Row

# %%
# 1.1.1 เริ่มจากการสร้างกำหนด List of list ขึ้นมา
technologies = [ ["Spark",20000, "30days"], 
                 ["pandas",20000, "40days"], 
               ]

# %%
# 1.1.2 นำ List of list จากข้อ 1.1.1 มาใช้กับ Constructor จะได้ Pandas Dataframe ที่มี Default Index Label
# ของทั้ง Row และ Column

import pandas as pd

pd.DataFrame(technologies)
# Out:
#         0      1       2
# 0   Spark  20000  30days
# 1  pandas  20000  40days

# %%
# 1.1.3 สร้าง List ขึ้นมาสองตัว ตัวหนึ่งใช้เป็น Row Index Label อีกตัวหนึ่งใช้เป็น Column Index Label
# จากนั้นนำ List ทั้งสองมาใช้เป็น Parameter ของ Constructor ก็จะได้ Pandas Dataframe เป็นผลลัพธ์
# ผลลัพธ์ต่างๆ จาก 1.1.2 ตรงที่ มี Index Label ที่ถูกสร้างขึ้นมาโดย user

row_label=["a","b"]

column_names=["Courses","Fee","Duration"]

pd.DataFrame(technologies,columns=column_names,index=row_label)
# Out:
#   Courses    Fee Duration
# a   Spark  20000   30days
# b  pandas  20000   40days

# %%
# 1.1.4 สร้าง List of Dict. (Dict. in List) ขึ้นมาบรรจุ Values และ Column Index Label
# สังเกตว่า มีการใช้ Zip กับ List 2 ตัว ที่มีจำนวน Element เท่ากัน
# โดย column_names เป็น List ที่เก็บ Column Index Label และ row เป็น List ที่เก็บ Values
# dict() เป็น Function ที่ให้เปลี่ยน​โครงสร้างข้อมูลให้เป็น Dictionary
# .append() เป็น Method ที่เพิ่ม Element เข้าไปใน List ซึ่งในที่นี้คือ raw_list 


raw_list = []

for row in technologies:
  raw_list.append(dict(zip(column_names,row)))

raw_list
# Out:
# [{'Courses': 'Spark', 'Fee': 20000, 'Duration': '30days'},
#  {'Courses': 'pandas', 'Fee': 20000, 'Duration': '40days'}]

# %%
# 1.1.5 นำ raw_list จาก 1.1.4 มาเป็น Parameter ของ Constructor
# สังเกตว่า ผลลัพธ์ที่ได้คือ Pandas Dataframe ที่ไม่มี Row Index Label
pd.DataFrame(raw_list)
# Out:
#   Courses    Fee Duration
# 0   Spark  20000   30days
# 1  pandas  20000   40days

# %%
# 1.1.6 เหมือนกับ 1.1.5 แต่ต่างตรงนี้ มีการเก็บผลลัพธ์ไว้เป็นตัวแปร raw_pd

raw_pd = pd.DataFrame(raw_list)

# %%
# 1.1.7 .info() เป็น Method ที่สรุปข้อมูลสำคัญของ Dataframe อาทิเช่น Class, Index (Rows), Columns,
# Data Types, Resource Usage เป็นต้น

raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Courses   2 non-null      object
#  1   Fee       2 non-null      int64
#  2   Duration  2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 176.0+ bytes

# %%
# 1.1.8 .astype() เป็น Method ที่ใช้เปลี่ยน Data Type ของ Columns ใน Dataframe
# สังเกตว่า Format ของ Data Type อยู่ในโครงสร้าง Dictionary

types={'Fee':float}

raw_pd=raw_pd.astype(types)

raw_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Courses   2 non-null      object
#  1   Fee       2 non-null      float64
#  2   Duration  2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 176.0+ bytes

# %% [markdown]
# ### **1.2 แนวทางที่ 2 ใช้ชุดของ value ใน Dictionary**
#
# วิธีนี้มีข้อสังเกตคือ เป็นการใช้ Dictionary เพียงชิ้นเดียว ไม่มี List of Dictionary เหมือนแนวทางแรก

# %%
# 1.2.1 สังเกตว่า มีการกำหนด Row Index Label ด้วย


import numpy as np

technologies   = {
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas",None,"Spark","Python"],
    'Fee' :[22000,25000,23000,24000,np.nan,25000,25000,22000],
    'Duration':['30day','50days','55days','40days','60days','35day','','50days'],
    'Discount':[1000,2300,1000,1200,2500,1300,1400,1600]
          }

row_labels=['r0','r1','r2','r3','r4','r5','r6','r7']

pd.DataFrame(technologies, index=row_labels)
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %% [markdown]
# # **2. Creating using File Reader**

# %%
# 2.1 เริ่มจากการใช้ wget ซึ่งเป็นคำสั่ง Linux ใช้ดาวน์โหลดไฟล์จาก URL

! wget https://storage.googleapis.com/5-7sep2022/data/titanic.csv
# Out:
# --2022-09-14 01:58:42--  https://storage.googleapis.com/5-7sep2022/data/titanic.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.128, 142.250.141.128, 2607:f8b0:4023:c0b::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [application/octet-stream]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  58.89K  --.-KB/s    in 0s
#
# 2022-09-14 01:58:43 (133 MB/s) - ‘titanic.csv’ saved [60302/60302]

# %%
# 2.2 สร้าง Pandas DataFrame จาก CSV File
pd.read_csv('titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# ข้อสังเกต คือ หากไม่ระบุ Parameter อื่นๆ เช่นนี้แล้ว จะใช้ Default Parameter ในการ Read
# Default Parameter เช่น na_filter = True ซึ่งจะเป็นการอ่าน Empty Value แล้วได้ NULL
pd.read_csv('titanic.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# อ่านแบบระบุ Parameter ซึ่งไม่ใช่ Default Parameter
pd.read_csv('titanic.csv', na_filter=False).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    object
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %%
# ตัวเลข 177 ด้านล่าง สะท้อนให้เห็นว่า na_filter=True ทำให้เกิด NULL ทั้งหมด 177 ค่า
raw_pd = pd.read_csv('titanic.csv', na_filter=False)
len(raw_pd[raw_pd['Age'] == ''])
# Out:
# 177

# %%
# อ่านแบบระบุ Parameter ซึ่งไม่ใช่ Default Parameter
pd.read_csv('titanic.csv', usecols=['Name','Sex','Age','Survived']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Name      891 non-null    object
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 28.0+ KB

# %%
#pd.set_option('display.max_rows', 1000)
